# %%
import torch

# %%
netG = ResNetGenerator()

# %%
model_path = '/content/horse2zebra_0.4.0.pth'
model_data = torch.load(model_path)
netG.load_state_dict(model_data)
# Out:
# <All keys matched successfully>

# %%
netG.eval()

# %%
from PIL import Image
from torchvision import transforms

# %%
preprocess = transforms.Compose([transforms.Resize(256),
                                 transforms.ToTensor()])

# %%
img = Image.open("/content/horse4.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x800 at 0x7F84144A56D0>

# %%
img_t = preprocess(img)
batch_t = torch.unsqueeze(img_t, 0)

# %%
batch_out = netG(batch_t)

# %%
out_t = (batch_out.data.squeeze() + 1.0) / 2.0
out_img = transforms.ToPILImage()(out_t)
# out_img.save('../data/p1ch2/zebra.jpg')
out_img
# Out:
# <PIL.Image.Image image mode=RGB size=384x256 at 0x7F84144BF790>
